# %%
import pandas as pnd
import numpy as np
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
import tensorflow as tf
import keras

tf.config.set_visible_devices([], 'GPU')

#Définition de la longueur et de la largeur de l'image
LONGUEUR_IMAGE = 28
LARGEUR_IMAGE = 28

#Chargement des images
observations_entrainement = pnd.read_csv('data/fashion-mnist_train.csv')

# %%
#On exclut la première colonne (les labels) pour constituer un tableau de pixels
X = np.array(observations_entrainement.iloc[:, 1:])

premiereImage = X[0]
premiereImage = premiereImage.reshape([LONGUEUR_IMAGE,LARGEUR_IMAGE])
plt.imshow(premiereImage)
plt.show()

# %%
#On crée des catégories à l'aide du module Keras
y = keras.utils.to_categorical(np.array(observations_entrainement.iloc[:,0]))
#Répartition des données d'entrainement en données d'apprentissage et données de validation
#80% de donnée d'apprentissage et 20% de donnée de validation
X_apprentissage, X_validation, y_apprentissage, y_validation = train_test_split(X, y, test_size=0.2, random_state=13)

# %%
# On redimensionne les images au format 28*28 et on réalise un scaling sur les données des pixels
X_apprentissage = X_apprentissage.reshape(X_apprentissage.shape[0], 
                                          LARGEUR_IMAGE, 
                                          LONGUEUR_IMAGE, 1)
X_apprentissage = X_apprentissage.astype('float32')
X_apprentissage /= 255

X_validation = X_validation.reshape(X_validation.shape[0], 
                                    LARGEUR_IMAGE, 
                                    LONGUEUR_IMAGE, 1)
X_validation = X_validation.astype('float32')
X_validation /= 255

# %%
#Preparation des données de tests
observations_test = pnd.read_csv('data/fashion-mnist_test.csv')
X_test = np.array(observations_test.iloc[:, 1:])
y_test = tf.keras.utils.to_categorical(np.array(observations_test.iloc[:, 0]))
X_test = X_test.reshape(X_test.shape[0], 
                        LARGEUR_IMAGE, 
                        LONGUEUR_IMAGE, 1)
X_test = X_test.astype('float32')
X_test /= 255

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Input
from keras.layers import Conv2D, MaxPooling2D

# On spécifie les dimensions de l'image d'entrée
dimentionImage = (LARGEUR_IMAGE, LONGUEUR_IMAGE, 1)

# On crée le réseau de neurones couche par couche
reseauNeurone1Convolution = Sequential()

# Ajout de la couche d'entrée
reseauNeurone1Convolution.add(Input(shape=dimentionImage))

#1- Ajout de la couche de convolution comportant
# 32 filtres de de taille 3x3 (Kernel) parcourant l'image
# Une fonction d'activation de type ReLU (Rectified Linear Activation)
# Une image d'entrée de 28px * 28 px 
reseauNeurone1Convolution.add(Conv2D(32, 
                                     kernel_size=(3, 3), 
                                     activation='relu'))

#2- Définition de la fonction de pooling avec une fenêtre de 2px sur 2 px
reseauNeurone1Convolution.add(MaxPooling2D(pool_size=(2, 2)))

#3- Ajout d'une fonction d'ignorance
reseauNeurone1Convolution.add(Dropout(0.2))

#5 - On transforme en une seule ligne
reseauNeurone1Convolution.add(Flatten())

#6 - Ajout d'un réseau de neurones composé de 128 neurones avec 
# une fonction d'activation de type ReLU
reseauNeurone1Convolution.add(Dense(128, activation='relu'))

#7 - Ajout d'un réseau de neurones composé de 10 neurones avec une 
# fonction d'activation de type softmax
reseauNeurone1Convolution.add(Dense(10, activation='softmax'))

# %%
reseauNeurone1Convolution.compile(loss=keras.losses.categorical_crossentropy, 
                                  optimizer=tf.keras.optimizers.Adam(), 
                                  metrics=['accuracy'])

# %%
historique_apprentissage = reseauNeurone1Convolution.fit(
    X_apprentissage, 
    y_apprentissage,
    batch_size=256,
    epochs=10,
    verbose=1,
    validation_data=(X_validation, y_validation))
# Out:
# Epoch 1/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8068 - loss: 0.5498 - val_accuracy: 0.8687 - val_loss: 0.3862
# Epoch 2/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.8690 - loss: 0.3677 - val_accuracy: 0.8752 - val_loss: 0.3549
# Epoch 3/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.8872 - loss: 0.3234 - val_accuracy: 0.8913 - val_loss: 0.3124
# Epoch 4/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.8959 - loss: 0.2933 - val_accuracy: 0.8908 - val_loss: 0.3044
# Epoch 5/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.9043 - loss: 0.2714 - val_accuracy: 0.8867 - val_loss: 0.3156
# Epoch 6/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.9086 - loss: 0.2568 - val_accuracy: 0.8995 - val_loss: 0.2812
# Epoch 7/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.9132 - loss: 0.2428 - val_accuracy: 0.9057 - val_loss: 0.2626
# Epoch 8/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.9182 - loss: 0.2268 - val_accuracy: 0.9066 - val_loss: 0.2612
# Epoch 9/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.9235 - loss: 0.2144 - val_accuracy: 0.9064 - val_loss: 0.2583
# Epoch 10/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9269 - loss: 0.2039 - val_accuracy: 0.9103 - val_loss: 0.2491

# %%
evaluation = reseauNeurone1Convolution.evaluate(X_test, y_test, verbose=0)
print('Erreur:', evaluation[0])
print('Précision:', evaluation[1])
# Out:
# Erreur: 0.2407027631998062
# Précision: 0.9135000109672546

# %%
plt.plot(historique_apprentissage.history['accuracy'])
plt.plot(historique_apprentissage.history['val_accuracy'])
plt.title('Précision du modèle')
plt.ylabel('Précision')
plt.xlabel('Epoch')
plt.legend(['Apprentissage', 'Test'], loc='upper left')
plt.show()
# Plot training & validation loss values
plt.plot(historique_apprentissage.history['loss'])
plt.plot(historique_apprentissage.history['val_loss'])
plt.title('Erreur')
plt.ylabel('Erreur')
plt.xlabel('Epoch')
plt.legend(['Apprentissage', 'Test'], loc='upper left')
plt.show()

# %% [markdown]
# # Modèle plus performant

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

generateur_images = tf.keras.preprocessing.image.ImageDataGenerator(
    rotation_range=8,
    width_shift_range=0.08,
    shear_range=0.3,
    height_shift_range=0.08,
    zoom_range=0.08)

# %%
nouvelles_images_apprentissage = generateur_images.flow(
    X_apprentissage, 
    y_apprentissage,
    batch_size=256)

nouvelles_images_validation = generateur_images.flow(
    X_validation, 
    y_validation,
    batch_size=256)

historique_apprentissage = reseauNeurone1Convolution.fit(
    nouvelles_images_apprentissage,
    steps_per_epoch=48000//256,
    epochs=50,
    validation_data=nouvelles_images_validation,
    validation_steps=12000//256,
    verbose=1 )

evaluation = reseauNeurone1Convolution.evaluate(X_test, y_test, verbose=0)

print('Erreur :', evaluation[0])
print('Précision:', evaluation[1])
# Out:
# Epoch 1/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - accuracy: 0.8271 - loss: 0.4670 - val_accuracy: 0.8385 - val_loss: 0.4330
# Epoch 2/50
#   1/187 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.8398 - loss: 0.4481
# /home/vscode/.local/lib/python3.12/site-packages/keras/src/trainers/epoch_iterator.py:116: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8398 - loss: 0.4481 - val_accuracy: 0.8360 - val_loss: 0.4299
# Epoch 3/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 7s 38ms/step - accuracy: 0.8470 - loss: 0.4124 - val_accuracy: 0.8512 - val_loss: 0.3986
# Epoch 4/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8359 - loss: 0.4355 - val_accuracy: 0.8530 - val_loss: 0.3987
# Epoch 5/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 7s 38ms/step - accuracy: 0.8536 - loss: 0.3927 - val_accuracy: 0.8683 - val_loss: 0.3671
# Epoch 6/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8516 - loss: 0.3936 - val_accuracy: 0.8638 - val_loss: 0.3734
# Epoch 7/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - accuracy: 0.8596 - loss: 0.3793 - val_accuracy: 0.8495 - val_loss: 0.3958
# Epoch 8/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8203 - loss: 0.4368 - val_accuracy: 0.8570 - val_loss: 0.3831
# Epoch 9/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - accuracy: 0.8645 - loss: 0.3657 - val_accuracy: 0.8668 - val_loss: 0.3578
# Epoch 10/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8750 - loss: 0.3015 - val_accuracy: 0.8697 - val_loss: 0.3503
# Epoch 11/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - accuracy: 0.8674 - loss: 0.3584 - val_accuracy: 0.8747 - val_loss: 0.3447
# Epoch 12/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8711 - loss: 0.3542 - val_accuracy: 0.8730 - val_loss: 0.3461
# Epoch 13/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - accuracy: 0.8718 - loss: 0.3446 - val_accuracy: 0.8702 - val_loss: 0.3433
# Epoch 14/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8594 - loss: 0.3591 - val_accuracy: 0.8760 - val_loss: 0.3360
# Epoch 15/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - accuracy: 0.8711 - loss: 0.3431 - val_accuracy: 0.8764 - val_loss: 0.3322
# Epoch 16/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ -1s -5899us/step - accuracy: 0.8867 - loss: 0.3372 - val_accuracy: 0.8800 - val_loss: 0.3271
# Epoch 17/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - accuracy: 0.8757 - loss: 0.3343 - val_accuracy: 0.8798 - val_loss: 0.3267
# Epoch 18/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9023 - loss: 0.2931 - val_accuracy: 0.8786 - val_loss: 0.3311
# Epoch 19/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 7s 38ms/step - accuracy: 0.8786 - loss: 0.3267 - val_accuracy: 0.8744 - val_loss: 0.3304
# Epoch 20/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8555 - loss: 0.3590 - val_accuracy: 0.8794 - val_loss: 0.3230
# Epoch 21/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - accuracy: 0.8803 - loss: 0.3238 - val_accuracy: 0.8797 - val_loss: 0.3202
# Epoch 22/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8750 - loss: 0.3207 - val_accuracy: 0.8828 - val_loss: 0.3247
# Epoch 23/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.8807 - loss: 0.3195 - val_accuracy: 0.8825 - val_loss: 0.3173
# Epoch 24/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8984 - loss: 0.2838 - val_accuracy: 0.8848 - val_loss: 0.3185
# Epoch 25/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - accuracy: 0.8834 - loss: 0.3118 - val_accuracy: 0.8846 - val_loss: 0.3163
# Epoch 26/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8867 - loss: 0.3484 - val_accuracy: 0.8847 - val_loss: 0.3174
# Epoch 27/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 7s 38ms/step - accuracy: 0.8827 - loss: 0.3149 - val_accuracy: 0.8822 - val_loss: 0.3221
# Epoch 28/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8633 - loss: 0.3471 - val_accuracy: 0.8809 - val_loss: 0.3121
# Epoch 29/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - accuracy: 0.8850 - loss: 0.3095 - val_accuracy: 0.8798 - val_loss: 0.3109
# Epoch 30/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8711 - loss: 0.3137 - val_accuracy: 0.8820 - val_loss: 0.3195
# Epoch 31/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.8870 - loss: 0.3031 - val_accuracy: 0.8885 - val_loss: 0.2988
# Epoch 32/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8984 - loss: 0.3086 - val_accuracy: 0.8888 - val_loss: 0.3055
# Epoch 33/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - accuracy: 0.8864 - loss: 0.3019 - val_accuracy: 0.8880 - val_loss: 0.3026
# Epoch 34/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8945 - loss: 0.3047 - val_accuracy: 0.8898 - val_loss: 0.2977
# Epoch 35/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 7s 38ms/step - accuracy: 0.8875 - loss: 0.3015 - val_accuracy: 0.8869 - val_loss: 0.3136
# Epoch 36/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9102 - loss: 0.2368 - val_accuracy: 0.8853 - val_loss: 0.3116
# Epoch 37/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 9s 49ms/step - accuracy: 0.8892 - loss: 0.2948 - val_accuracy: 0.8910 - val_loss: 0.2938
# Epoch 38/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ -3s 6ms/step - accuracy: 0.8594 - loss: 0.3099 - val_accuracy: 0.8890 - val_loss: 0.3004
# Epoch 39/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - accuracy: 0.8900 - loss: 0.2964 - val_accuracy: 0.8937 - val_loss: 0.2942
# Epoch 40/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8789 - loss: 0.3069 - val_accuracy: 0.8918 - val_loss: 0.2994
# Epoch 41/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - accuracy: 0.8936 - loss: 0.2886 - val_accuracy: 0.8910 - val_loss: 0.2965
# Epoch 42/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8125 - loss: 0.4918 - val_accuracy: 0.8904 - val_loss: 0.2934
# Epoch 43/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - accuracy: 0.8937 - loss: 0.2861 - val_accuracy: 0.8888 - val_loss: 0.3064
# Epoch 44/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8828 - loss: 0.3636 - val_accuracy: 0.8920 - val_loss: 0.2958
# Epoch 45/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - accuracy: 0.8951 - loss: 0.2837 - val_accuracy: 0.8899 - val_loss: 0.2948
# Epoch 46/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9102 - loss: 0.2805 - val_accuracy: 0.8857 - val_loss: 0.3089
# Epoch 47/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - accuracy: 0.8933 - loss: 0.2847 - val_accuracy: 0.8906 - val_loss: 0.2997
# Epoch 48/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8906 - loss: 0.2709 - val_accuracy: 0.8922 - val_loss: 0.2861
# Epoch 49/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 7s 38ms/step - accuracy: 0.8966 - loss: 0.2805 - val_accuracy: 0.8909 - val_loss: 0.2919
# Epoch 50/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8750 - loss: 0.3458 - val_accuracy: 0.8992 - val_loss: 0.2785
# Erreur : 0.22537510097026825
# Précision: 0.9186999797821045

# %%
#Sauvegarde du modèle
# Serialisation du modèle 
model_json = reseauNeurone1Convolution.to_json() 
with open("modele/modele.json", "w") as json_file:
    json_file.write(model_json)
    
# Serialisation des poids
reseauNeurone1Convolution.save_weights("modele/modele.weights.h5")
print("Modèle sauvegardé !")
# Out:
# Modèle sauvegardé !

# %%
from keras.layers import BatchNormalization

reseauNeurones4Convolution = Sequential()

reseauNeurones4Convolution.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=dimentionImage))
reseauNeurones4Convolution.add(BatchNormalization())
reseauNeurones4Convolution.add(Conv2D(32, kernel_size=(3, 3), activation='relu'))
reseauNeurones4Convolution.add(BatchNormalization())
reseauNeurones4Convolution.add(MaxPooling2D(pool_size=(2, 2)))
reseauNeurones4Convolution.add(Dropout(0.25))

reseauNeurones4Convolution.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
reseauNeurones4Convolution.add(BatchNormalization())
reseauNeurones4Convolution.add(Dropout(0.25))

reseauNeurones4Convolution.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
reseauNeurones4Convolution.add(BatchNormalization())
reseauNeurones4Convolution.add(MaxPooling2D(pool_size=(2, 2)))
reseauNeurones4Convolution.add(Dropout(0.25))

reseauNeurones4Convolution.add(Flatten())
reseauNeurones4Convolution.add(Dense(512, activation='relu'))
reseauNeurones4Convolution.add(BatchNormalization())
reseauNeurones4Convolution.add(Dropout(0.5))

reseauNeurones4Convolution.add(Dense(128, activation='relu'))
reseauNeurones4Convolution.add(BatchNormalization())
reseauNeurones4Convolution.add(Dropout(0.5))

reseauNeurones4Convolution.add(Dense(10, activation='softmax'))
# Out:
# /home/vscode/.local/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
reseauNeurones4Convolution.compile(loss=keras.losses.categorical_crossentropy, 
                                  optimizer=tf.keras.optimizers.Adam(), 
                                  metrics=['accuracy'])

historique_apprentissage = reseauNeurones4Convolution.fit(
    X_apprentissage, 
    y_apprentissage,
    batch_size=256,
    epochs=10,
    verbose=1,
    validation_data=(X_validation, y_validation))
# Out:
# Epoch 1/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 23s 86ms/step - accuracy: 0.7414 - loss: 0.7466 - val_accuracy: 0.1567 - val_loss: 2.9187
# Epoch 2/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 15s 78ms/step - accuracy: 0.8404 - loss: 0.4443 - val_accuracy: 0.5691 - val_loss: 1.3574
# Epoch 3/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 18s 93ms/step - accuracy: 0.8705 - loss: 0.3651 - val_accuracy: 0.8142 - val_loss: 0.5194
# Epoch 4/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 15s 81ms/step - accuracy: 0.8797 - loss: 0.3344 - val_accuracy: 0.8871 - val_loss: 0.3167
# Epoch 5/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 18s 93ms/step - accuracy: 0.8928 - loss: 0.3016 - val_accuracy: 0.9014 - val_loss: 0.2734
# Epoch 6/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 15s 82ms/step - accuracy: 0.8976 - loss: 0.2867 - val_accuracy: 0.9090 - val_loss: 0.2470
# Epoch 7/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 15s 82ms/step - accuracy: 0.9053 - loss: 0.2664 - val_accuracy: 0.9107 - val_loss: 0.2393
# Epoch 8/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 18s 93ms/step - accuracy: 0.9081 - loss: 0.2579 - val_accuracy: 0.9058 - val_loss: 0.2554
# Epoch 9/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 15s 81ms/step - accuracy: 0.9116 - loss: 0.2457 - val_accuracy: 0.9058 - val_loss: 0.2525
# Epoch 10/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 18s 94ms/step - accuracy: 0.9156 - loss: 0.2366 - val_accuracy: 0.9175 - val_loss: 0.2277

# %%
evaluation = reseauNeurones4Convolution.evaluate(X_test, y_test, verbose=0)
print('Erreur:', evaluation[0])
print('Précision:', evaluation[1])
# Out:
# Erreur: 0.20689992606639862
# Précision: 0.9243000149726868

# %%
historique_apprentissage = reseauNeurones4Convolution.fit(
    nouvelles_images_apprentissage,
    steps_per_epoch=48000//256,
    epochs=50,
    validation_data=nouvelles_images_validation,
    validation_steps=12000//256,
    verbose=1 )

evaluation = reseauNeurones4Convolution.evaluate(X_test, y_test, verbose=0)

print('Erreur :', evaluation[0])
print('Précision:', evaluation[1])
# Out:
# Epoch 1/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 16s 77ms/step - accuracy: 0.8570 - loss: 0.3999 - val_accuracy: 0.8776 - val_loss: 0.3274
# Epoch 2/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8984 - loss: 0.2800 - val_accuracy: 0.8802 - val_loss: 0.3229
# Epoch 3/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 15s 77ms/step - accuracy: 0.8701 - loss: 0.3614 - val_accuracy: 0.8853 - val_loss: 0.3155
# Epoch 4/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8477 - loss: 0.3929 - val_accuracy: 0.8867 - val_loss: 0.3127
# Epoch 5/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 18s 96ms/step - accuracy: 0.8750 - loss: 0.3422 - val_accuracy: 0.8837 - val_loss: 0.3115
# Epoch 6/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8477 - loss: 0.3945 - val_accuracy: 0.8850 - val_loss: 0.3116
# Epoch 7/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 16s 84ms/step - accuracy: 0.8805 - loss: 0.3324 - val_accuracy: 0.8879 - val_loss: 0.2966
# Epoch 8/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8828 - loss: 0.3065 - val_accuracy: 0.8899 - val_loss: 0.2978
# Epoch 9/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 16s 86ms/step - accuracy: 0.8827 - loss: 0.3230 - val_accuracy: 0.8964 - val_loss: 0.2831
# Epoch 10/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8906 - loss: 0.2689 - val_accuracy: 0.8972 - val_loss: 0.2805
# Epoch 11/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 18s 98ms/step - accuracy: 0.8867 - loss: 0.3137 - val_accuracy: 0.9010 - val_loss: 0.2749
# Epoch 12/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8750 - loss: 0.3321 - val_accuracy: 0.8985 - val_loss: 0.2762
# Epoch 13/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 16s 85ms/step - accuracy: 0.8875 - loss: 0.3076 - val_accuracy: 0.9028 - val_loss: 0.2710
# Epoch 14/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8789 - loss: 0.3367 - val_accuracy: 0.9007 - val_loss: 0.2664
# Epoch 15/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 16s 86ms/step - accuracy: 0.8898 - loss: 0.3008 - val_accuracy: 0.9009 - val_loss: 0.2651
# Epoch 16/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8516 - loss: 0.3752 - val_accuracy: 0.9007 - val_loss: 0.2702
# Epoch 17/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 18s 99ms/step - accuracy: 0.8904 - loss: 0.3016 - val_accuracy: 0.8863 - val_loss: 0.3024
# Epoch 18/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8789 - loss: 0.3660 - val_accuracy: 0.8982 - val_loss: 0.2754
# Epoch 19/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 16s 85ms/step - accuracy: 0.8925 - loss: 0.2945 - val_accuracy: 0.9006 - val_loss: 0.2777
# Epoch 20/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8906 - loss: 0.2518 - val_accuracy: 0.8995 - val_loss: 0.2730
# Epoch 21/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 16s 86ms/step - accuracy: 0.8952 - loss: 0.2879 - val_accuracy: 0.8975 - val_loss: 0.2755
# Epoch 22/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9219 - loss: 0.2482 - val_accuracy: 0.8918 - val_loss: 0.2840
# Epoch 23/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 18s 99ms/step - accuracy: 0.8975 - loss: 0.2789 - val_accuracy: 0.9062 - val_loss: 0.2555
# Epoch 24/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8594 - loss: 0.3538 - val_accuracy: 0.9040 - val_loss: 0.2561
# Epoch 25/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 16s 85ms/step - accuracy: 0.8960 - loss: 0.2868 - val_accuracy: 0.9061 - val_loss: 0.2573
# Epoch 26/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8789 - loss: 0.3431 - val_accuracy: 0.9038 - val_loss: 0.2587
# Epoch 27/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 16s 85ms/step - accuracy: 0.9000 - loss: 0.2768 - val_accuracy: 0.9072 - val_loss: 0.2458
# Epoch 28/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9023 - loss: 0.3094 - val_accuracy: 0.9051 - val_loss: 0.2486
# Epoch 29/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 19s 99ms/step - accuracy: 0.9018 - loss: 0.2748 - val_accuracy: 0.9077 - val_loss: 0.2496
# Epoch 30/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8945 - loss: 0.2666 - val_accuracy: 0.9126 - val_loss: 0.2403
# Epoch 31/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 16s 85ms/step - accuracy: 0.9010 - loss: 0.2711 - val_accuracy: 0.9096 - val_loss: 0.2480
# Epoch 32/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9141 - loss: 0.2449 - val_accuracy: 0.9068 - val_loss: 0.2542
# Epoch 33/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 16s 86ms/step - accuracy: 0.9020 - loss: 0.2691 - val_accuracy: 0.9049 - val_loss: 0.2536
# Epoch 34/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8789 - loss: 0.2557 - val_accuracy: 0.9083 - val_loss: 0.2456
# Epoch 35/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 18s 98ms/step - accuracy: 0.9034 - loss: 0.2654 - val_accuracy: 0.9106 - val_loss: 0.2525
# Epoch 36/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9180 - loss: 0.2520 - val_accuracy: 0.9066 - val_loss: 0.2570
# Epoch 37/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 16s 85ms/step - accuracy: 0.9044 - loss: 0.2615 - val_accuracy: 0.9055 - val_loss: 0.2529
# Epoch 38/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8672 - loss: 0.3545 - val_accuracy: 0.9002 - val_loss: 0.2652
# Epoch 39/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 16s 85ms/step - accuracy: 0.9065 - loss: 0.2607 - val_accuracy: 0.9051 - val_loss: 0.2590
# Epoch 40/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9141 - loss: 0.2507 - val_accuracy: 0.9023 - val_loss: 0.2672
# Epoch 41/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 18s 98ms/step - accuracy: 0.9042 - loss: 0.2653 - val_accuracy: 0.9113 - val_loss: 0.2359
# Epoch 42/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8945 - loss: 0.2724 - val_accuracy: 0.9122 - val_loss: 0.2392
# Epoch 43/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 16s 85ms/step - accuracy: 0.9074 - loss: 0.2539 - val_accuracy: 0.9157 - val_loss: 0.2410
# Epoch 44/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9258 - loss: 0.2340 - val_accuracy: 0.9105 - val_loss: 0.2430
# Epoch 45/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 16s 85ms/step - accuracy: 0.9078 - loss: 0.2569 - val_accuracy: 0.9099 - val_loss: 0.2441
# Epoch 46/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8867 - loss: 0.2939 - val_accuracy: 0.9050 - val_loss: 0.2508
# Epoch 47/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 19s 99ms/step - accuracy: 0.9062 - loss: 0.2556 - val_accuracy: 0.9177 - val_loss: 0.2262
# Epoch 48/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9297 - loss: 0.1950 - val_accuracy: 0.9169 - val_loss: 0.2315
# Epoch 49/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 16s 87ms/step - accuracy: 0.9103 - loss: 0.2481 - val_accuracy: 0.9102 - val_loss: 0.2439
# Epoch 50/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9141 - loss: 0.2517 - val_accuracy: 0.9104 - val_loss: 0.2460
# Erreur : 0.18958282470703125
# Précision: 0.9289000034332275

# %%
model_json = reseauNeurone1Convolution.to_json() 
with open("modele/modele2.json", "w") as json_file:
    json_file.write(model_json)
    
# Serialisation des poids
reseauNeurone1Convolution.save_weights("modele/modele2.weights.h5")
print("Modèle sauvegardé !")
# Out:
# Modèle sauvegardé !
